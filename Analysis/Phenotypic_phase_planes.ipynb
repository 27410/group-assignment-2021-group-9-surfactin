# %%
# %run model.ipynb

# %%
from cobra.flux_analysis.phenotype_phase_plane import production_envelope

# %%
print(model.objective)
# Out:
# Maximize
# 1.0*BIOMASS_BS_10 - 1.0*BIOMASS_BS_10_reverse_8788b

# %% [markdown]
# Phenotypic phase plan for biomass on glucose

# %%
ppp_biomass = production_envelope(model,
                    reactions=[model.reactions.EX_glc__D_e],
                    objective=model.reactions.BIOMASS_BS_10)
ppp_biomass
# Out:
#    carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0    EX_glc__D_e           0.0                   0.0                 NaN
# 1    EX_glc__D_e           0.0                   0.0                 NaN
# 2    EX_glc__D_e           0.0                   0.0                 NaN
# 3    EX_glc__D_e           0.0                   0.0                 NaN
# 4    EX_glc__D_e           0.0                   0.0                 NaN
# 5    EX_glc__D_e           0.0                   0.0                 NaN
# 6    EX_glc__D_e           0.0                   0.0                 NaN
# 7    EX_glc__D_e           0.0                   0.0                 NaN
# 8    EX_glc__D_e           0.0                   0.0                 NaN
# 9    EX_glc__D_e           0.0                   0.0                 NaN
# 10   EX_glc__D_e           0.0                   0.0                 NaN
# 11   EX_glc__D_e           0.0                   0.0                 NaN
# 12   EX_glc__D_e           0.0                   0.0                 NaN
# 13   EX_glc__D_e           0.0                   0.0                 NaN
# 14   EX_glc__D_e           0.0                   0.0                 NaN
# 15   EX_glc__D_e           0.0                   0.0                 NaN
# 16   EX_glc__D_e           0.0                   0.0                 NaN
# 17   EX_glc__D_e           0.0                   0.0                 NaN
# 18   EX_glc__D_e           0.0                   0.0                 NaN
# 19   EX_glc__D_e           0.0                   0.0                 NaN
#
#     flux_maximum  carbon_yield_maximum  mass_yield_maximum  EX_glc__D_e
# 0       0.117966          1.255696e+01                 NaN    -1.700000
# 1       0.111758          1.240494e+01                 NaN    -1.630263
# 2       0.105549          1.223933e+01                 NaN    -1.560526
# 3       0.099340          1.205823e+01                 NaN    -1.490789
# 4       0.093131          1.185935e+01                 NaN    -1.421053
# 5       0.086923          1.163995e+01                 NaN    -1.351316
# 6       0.080714          1.139667e+01                 NaN    -1.281579
# 7       0.074505          1.112538e+01                 NaN    -1.211842
# 8       0.068296          1.082097e+01                 NaN    -1.142105
# 9       0.062088          1.047697e+01                 NaN    -1.072368
# 10      0.055879          1.008512e+01                 NaN    -1.002632
# 11      0.049670          9.634677e+00                 NaN    -0.932895
# 12      0.043461          9.111452e+00                 NaN    -0.863158
# 13      0.037253          8.496251e+00                 NaN    -0.793421
# 14      0.031044          7.762484e+00                 NaN    -0.723684
# 15      0.024835          6.872219e+00                 NaN    -0.653947
# 16      0.018626          5.769414e+00                 NaN    -0.584211
# 17      0.012418          4.367638e+00                 NaN    -0.514474
# 18      0.006209          2.526252e+00                 NaN    -0.444737
# 19      0.000000          1.660735e-13                 NaN    -0.375000

# %%
ppp_biomass.plot(x='EX_glc__D_e', y='flux_maximum')
# Out:
# <AxesSubplot:xlabel='EX_glc__D_e'>

# %% [markdown]
# PPP for surfactin on glucose

# %%
ppp_surfactin = production_envelope(model,
                    reactions=[model.reactions.EX_glc__D_e],
                    objective=model.reactions.DM_surfactin_c)
ppp_surfactin
# Out:
#    carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0    EX_glc__D_e           0.0                   0.0                 0.0
# 1    EX_glc__D_e           0.0                   0.0                 0.0
# 2    EX_glc__D_e           0.0                   0.0                 0.0
# 3    EX_glc__D_e           0.0                   0.0                 0.0
# 4    EX_glc__D_e           0.0                   0.0                 0.0
# 5    EX_glc__D_e           0.0                   0.0                 0.0
# 6    EX_glc__D_e           0.0                   0.0                 0.0
# 7    EX_glc__D_e           0.0                   0.0                 0.0
# 8    EX_glc__D_e           0.0                   0.0                 0.0
# 9    EX_glc__D_e           0.0                   0.0                 0.0
# 10   EX_glc__D_e           0.0                   0.0                 0.0
# 11   EX_glc__D_e           0.0                   0.0                 0.0
# 12   EX_glc__D_e           0.0                   0.0                 0.0
# 13   EX_glc__D_e           0.0                   0.0                 0.0
# 14   EX_glc__D_e           0.0                   0.0                 0.0
# 15   EX_glc__D_e           0.0                   0.0                 0.0
# 16   EX_glc__D_e           0.0                   0.0                 0.0
# 17   EX_glc__D_e           0.0                   0.0                 0.0
# 18   EX_glc__D_e           0.0                   0.0                 0.0
# 19   EX_glc__D_e           0.0                   0.0                 0.0
#
#     flux_maximum  carbon_yield_maximum  mass_yield_maximum  EX_glc__D_e
# 0       0.092988                   0.0                 0.0    -1.700000
# 1       0.088127                   0.0                 0.0    -1.630263
# 2       0.083267                   0.0                 0.0    -1.560526
# 3       0.078406                   0.0                 0.0    -1.490789
# 4       0.073546                   0.0                 0.0    -1.421053
# 5       0.068685                   0.0                 0.0    -1.351316
# 6       0.063824                   0.0                 0.0    -1.281579
# 7       0.058941                   0.0                 0.0    -1.211842
# 8       0.054029                   0.0                 0.0    -1.142105
# 9       0.049118                   0.0                 0.0    -1.072368
# 10      0.044206                   0.0                 0.0    -1.002632
# 11      0.039294                   0.0                 0.0    -0.932895
# 12      0.034382                   0.0                 0.0    -0.863158
# 13      0.029471                   0.0                 0.0    -0.793421
# 14      0.024559                   0.0                 0.0    -0.723684
# 15      0.019647                   0.0                 0.0    -0.653947
# 16      0.014735                   0.0                 0.0    -0.584211
# 17      0.009824                   0.0                 0.0    -0.514474
# 18      0.004912                   0.0                 0.0    -0.444737
# 19      0.000000                   0.0                 0.0    -0.375000

# %%
ppp_surfactin.plot(x='EX_glc__D_e',y='flux_maximum')
# Out:
# <AxesSubplot:xlabel='EX_glc__D_e'>

# %% [markdown]
# Testing production for aerobic vs anaerobic

# %%
medium = model.medium
with model:
    medium['EX_o2_e'] = 0
    model.medium = medium
    solution = model.optimize()
    print(solution.fluxes['BIOMASS_BS_10'])
# Out:
# 0.0
# C:\Users\Natasha\anaconda3\envs\Cell factory\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)

# %% [markdown]
# Not viable, our organism cannot grow without oxygen so therefore we are going to look at the flux changes dependant on media

# %%
# %run model_sucrose.ipynb

# %% [markdown]
# PPP for surfactin on sucrose

# %%
ppp_surfactin1 = production_envelope(model,
                    reactions=[model.reactions.EX_sucr_e],
                    objective=model.reactions.DM_surfactin_c)
ppp_surfactin1
# Out:
#    carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0      EX_sucr_e           0.0                   0.0                 0.0
# 1      EX_sucr_e           0.0                   0.0                 0.0
# 2      EX_sucr_e           0.0                   0.0                 0.0
# 3      EX_sucr_e           0.0                   0.0                 0.0
# 4      EX_sucr_e           0.0                   0.0                 0.0
# 5      EX_sucr_e           0.0                   0.0                 0.0
# 6      EX_sucr_e           0.0                   0.0                 0.0
# 7      EX_sucr_e           0.0                   0.0                 0.0
# 8      EX_sucr_e           0.0                   0.0                 0.0
# 9      EX_sucr_e           0.0                   0.0                 0.0
# 10     EX_sucr_e           0.0                   0.0                 0.0
# 11     EX_sucr_e           0.0                   0.0                 0.0
# 12     EX_sucr_e           0.0                   0.0                 0.0
# 13     EX_sucr_e           0.0                   0.0                 0.0
# 14     EX_sucr_e           0.0                   0.0                 0.0
# 15     EX_sucr_e           0.0                   0.0                 0.0
# 16     EX_sucr_e           0.0                   0.0                 0.0
# 17     EX_sucr_e           0.0                   0.0                 0.0
# 18     EX_sucr_e           0.0                   0.0                 0.0
# 19     EX_sucr_e           0.0                   0.0                 0.0
#
#     flux_maximum  carbon_yield_maximum  mass_yield_maximum    EX_sucr_e
# 0       0.357143                   0.0                 0.0 -1000.000000
# 1       0.357143                   0.0                 0.0  -947.378289
# 2       0.357143                   0.0                 0.0  -894.756579
# 3       0.357143                   0.0                 0.0  -842.134868
# 4       0.357143                   0.0                 0.0  -789.513158
# 5       0.357143                   0.0                 0.0  -736.891447
# 6       0.357143                   0.0                 0.0  -684.269737
# 7       0.357143                   0.0                 0.0  -631.648026
# 8       0.357143                   0.0                 0.0  -579.026316
# 9       0.357143                   0.0                 0.0  -526.404605
# 10      0.357143                   0.0                 0.0  -473.782895
# 11      0.357143                   0.0                 0.0  -421.161184
# 12      0.357143                   0.0                 0.0  -368.539474
# 13      0.357143                   0.0                 0.0  -315.917763
# 14      0.357143                   0.0                 0.0  -263.296053
# 15      0.357143                   0.0                 0.0  -210.674342
# 16      0.357143                   0.0                 0.0  -158.052632
# 17      0.357143                   0.0                 0.0  -105.430921
# 18      0.357143                   0.0                 0.0   -52.809211
# 19      0.000000                   0.0                 0.0    -0.187500

# %%
ppp_surfactin1.plot(x='EX_sucr_e',y='flux_maximum')
# Out:
# <AxesSubplot:xlabel='EX_sucr_e'>

# %% [markdown]
# PPP for biomass on sucrose

# %%
ppp_biomass = production_envelope(model,
                    reactions=[model.reactions.EX_sucr_e],
                    objective=model.reactions.BIOMASS_BS_10)
ppp_biomass
# Out:
#    carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0      EX_sucr_e           0.0                   0.0                 NaN
# 1      EX_sucr_e           0.0                   0.0                 NaN
# 2      EX_sucr_e           0.0                   0.0                 NaN
# 3      EX_sucr_e           0.0                   0.0                 NaN
# 4      EX_sucr_e           0.0                   0.0                 NaN
# 5      EX_sucr_e           0.0                   0.0                 NaN
# 6      EX_sucr_e           0.0                   0.0                 NaN
# 7      EX_sucr_e           0.0                   0.0                 NaN
# 8      EX_sucr_e           0.0                   0.0                 NaN
# 9      EX_sucr_e           0.0                   0.0                 NaN
# 10     EX_sucr_e           0.0                   0.0                 NaN
# 11     EX_sucr_e           0.0                   0.0                 NaN
# 12     EX_sucr_e           0.0                   0.0                 NaN
# 13     EX_sucr_e           0.0                   0.0                 NaN
# 14     EX_sucr_e           0.0                   0.0                 NaN
# 15     EX_sucr_e           0.0                   0.0                 NaN
# 16     EX_sucr_e           0.0                   0.0                 NaN
# 17     EX_sucr_e           0.0                   0.0                 NaN
# 18     EX_sucr_e           0.0                   0.0                 NaN
# 19     EX_sucr_e           0.0                   0.0                 NaN
#
#     flux_maximum  carbon_yield_maximum  mass_yield_maximum    EX_sucr_e
# 0       0.624185          5.647527e-02                 NaN -1000.000000
# 1       0.624185          5.961216e-02                 NaN  -947.378289
# 2       0.624185          6.311803e-02                 NaN  -894.756579
# 3       0.624185          6.706203e-02                 NaN  -842.134868
# 4       0.624185          7.153177e-02                 NaN  -789.513158
# 5       0.624185          7.663988e-02                 NaN  -736.891447
# 6       0.624185          8.253364e-02                 NaN  -684.269737
# 7       0.624185          8.940940e-02                 NaN  -631.648026
# 8       0.624185          9.753489e-02                 NaN  -579.026316
# 9       0.624185          1.072849e-01                 NaN  -526.404605
# 10      0.624185          1.192007e-01                 NaN  -473.782895
# 11      0.624185          1.340942e-01                 NaN  -421.161184
# 12      0.624185          1.532408e-01                 NaN  -368.539474
# 13      0.624185          1.787657e-01                 NaN  -315.917763
# 14      0.624185          2.144934e-01                 NaN  -263.296053
# 15      0.624185          2.680690e-01                 NaN  -210.674342
# 16      0.624185          3.573194e-01                 NaN  -158.052632
# 17      0.624185          5.356614e-01                 NaN  -105.430921
# 18      0.624185          1.069421e+00                 NaN   -52.809211
# 19      0.000000          1.251762e-07                 NaN    -0.187500

# %%
ppp_biomass.plot(x='EX_sucr_e', y='flux_maximum')
# Out:
# <AxesSubplot:xlabel='EX_sucr_e'>

# %% [markdown]
# Results show that growth on glucose is better but surfactin production is better on sucrose.
