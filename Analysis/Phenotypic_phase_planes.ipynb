# %%
# %run model.ipynb #running model on glucose

# %% [markdown]
# ### Phenotypic Phase Plane Analysis

# %%
from cobra.flux_analysis.phenotype_phase_plane import production_envelope

# %% [markdown]
# #### PPP for biomass on glucose

# %%
ppp_biomass = production_envelope(model,
                    reactions=[model.reactions.EX_glc__D_e],
                    objective=model.reactions.BIOMASS_BS_10)
ppp_biomass
# Out:
#    carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0    EX_glc__D_e      0.023593              2.511392                 NaN
# 1    EX_glc__D_e      0.023593              2.596605                 NaN
# 2    EX_glc__D_e      0.023593              2.687805                 NaN
# 3    EX_glc__D_e      0.023593              2.785644                 NaN
# 4    EX_glc__D_e      0.023593              2.890875                 NaN
# 5    EX_glc__D_e      0.023593              3.004369                 NaN
# 6    EX_glc__D_e      0.023593              3.127138                 NaN
# 7    EX_glc__D_e      0.023593              3.260368                 NaN
# 8    EX_glc__D_e      0.023593              3.405456                 NaN
# 9    EX_glc__D_e      0.023593              3.564058                 NaN
# 10   EX_glc__D_e      0.023593              3.738155                 NaN
# 11   EX_glc__D_e      0.023593              3.930134                 NaN
# ...

# %%
ppp_biomass.plot(x='EX_glc__D_e', y='flux_maximum', title="Biomass flux on glucose",ylabel="Biomass") #Plotting the ppp
# Out:
# <AxesSubplot:title={'center':'Biomass flux on glucose'}, xlabel='EX_glc__D_e', ylabel='Biomass'>

# %% [markdown]
# #### PPP for surfactin on glucose

# %%
ppp_surfactin = production_envelope(model,
                    reactions=[model.reactions.EX_glc__D_e],
                    objective=model.reactions.DM_surfactin_c)
ppp_surfactin
# Out:
#    carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0    EX_glc__D_e           0.0                   0.0                 0.0
# 1    EX_glc__D_e           0.0                   0.0                 0.0
# 2    EX_glc__D_e           0.0                   0.0                 0.0
# 3    EX_glc__D_e           0.0                   0.0                 0.0
# 4    EX_glc__D_e           0.0                   0.0                 0.0
# 5    EX_glc__D_e           0.0                   0.0                 0.0
# 6    EX_glc__D_e           0.0                   0.0                 0.0
# 7    EX_glc__D_e           0.0                   0.0                 0.0
# 8    EX_glc__D_e           0.0                   0.0                 0.0
# 9    EX_glc__D_e           0.0                   0.0                 0.0
# 10   EX_glc__D_e           0.0                   0.0                 0.0
# 11   EX_glc__D_e           0.0                   0.0                 0.0
# ...

# %%
ppp_surfactin.plot(x='EX_glc__D_e',y='flux_maximum',title="Surfactin flux on glucose",ylabel="Surfactin") #plotting the ppp
# Out:
# <AxesSubplot:title={'center':'Surfactin flux on glucose'}, xlabel='EX_glc__D_e', ylabel='Surfactin'>

# %% [markdown]
# #### Testing surfactin production for aerobic vs anaerobic conditions

# %%
medium = model.medium
with model:
    medium['EX_o2_e'] = 0 #removing oxygen from medium
    model.medium = medium #defining medium without O
    solution = model.optimize() #optimizing this solution
    print(solution.fluxes['BIOMASS_BS_10'])
# Out:
# 0.02359327786447964
# C:\Users\Natasha\anaconda3\envs\Cell factory\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)

# %% [markdown]
# Not viable, our organism cannot grow without oxygen.

# %% [markdown]
# #### PPP for surfactin on sucrose

# %%
# %run model_sucrose.ipynb #calling model with sucrose media

# %%
ppp_surfactin1 = production_envelope(model,
                    reactions=[model.reactions.EX_sucr_e],
                    objective=model.reactions.DM_surfactin_c)
ppp_surfactin1
# Out:
#    carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0      EX_sucr_e           0.0                   0.0                 0.0
# 1      EX_sucr_e           0.0                   0.0                 0.0
# 2      EX_sucr_e           0.0                   0.0                 0.0
# 3      EX_sucr_e           0.0                   0.0                 0.0
# 4      EX_sucr_e           0.0                   0.0                 0.0
# 5      EX_sucr_e           0.0                   0.0                 0.0
# 6      EX_sucr_e           0.0                   0.0                 0.0
# 7      EX_sucr_e           0.0                   0.0                 0.0
# 8      EX_sucr_e           0.0                   0.0                 0.0
# 9      EX_sucr_e           0.0                   0.0                 0.0
# 10     EX_sucr_e           0.0                   0.0                 0.0
# 11     EX_sucr_e           0.0                   0.0                 0.0
# ...

# %%
ppp_surfactin1.plot(x='EX_sucr_e',y='flux_maximum',xlim=[-100,2],title="Surfactin flux on sucrose",ylabel="Surfactin") #plotting ppp
# Out:
# <AxesSubplot:title={'center':'Surfactin flux on sucrose'}, xlabel='EX_sucr_e', ylabel='Surfactin'>

# %% [markdown]
# #### PPP for biomass on sucrose

# %%
ppp_biomass = production_envelope(model,
                    reactions=[model.reactions.EX_sucr_e],
                    objective=model.reactions.BIOMASS_BS_10)
ppp_biomass
# Out:
#    carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0      EX_sucr_e      0.023593              0.002135                 NaN
# 1      EX_sucr_e      0.023593              0.002253                 NaN
# 2      EX_sucr_e      0.023593              0.002386                 NaN
# 3      EX_sucr_e      0.023593              0.002535                 NaN
# 4      EX_sucr_e      0.023593              0.002704                 NaN
# 5      EX_sucr_e      0.023593              0.002897                 NaN
# 6      EX_sucr_e      0.023593              0.003119                 NaN
# 7      EX_sucr_e      0.023593              0.003379                 NaN
# 8      EX_sucr_e      0.023593              0.003686                 NaN
# 9      EX_sucr_e      0.023593              0.004055                 NaN
# 10     EX_sucr_e      0.023593              0.004505                 NaN
# 11     EX_sucr_e      0.023593              0.005068                 NaN
# ...

# %%
ppp_biomass.plot(x='EX_sucr_e', y='flux_maximum',xlim=[-100,2], title="Biomass flux on sucrose",ylabel="Surfactin") #plotting the ppp
# Out:
# <AxesSubplot:title={'center':'Biomass flux on sucrose'}, xlabel='EX_sucr_e', ylabel='Surfactin'>

# %% [markdown]
# Results show that growth on glucose is better than on sucrose but surfactin production is better on sucrose.
