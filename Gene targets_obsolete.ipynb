# %% [markdown]
# importing model with surfactin

# %%
# %run model_sucrose.ipynb

# %%
import numpy as np

# %%
from cameo.strain_design.deterministic.flux_variability_based import FSEOF
fseof = FSEOF(model)
result = fseof.run(target = model.reactions.DM_surfactin_c)
df = result.data_frame

# %%
from matplotlib import pyplot as plt
result.data_frame.T.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
# sorting 
df= df.sort_values([1], ascending = False)
 
# removing genes from dataframe 
removed_zero = (df[1] != 0)
df = df.loc[removed_zero]

df.head()
# Out:
#                1          2          3          4          5          6   \
# ATPS4r  62.612368  57.187515  51.762662  46.337809  41.668253  37.249920
# NADH4   37.472065  34.290564  31.109064  27.927563  25.153216  22.513634
# CYOO3   37.472065  34.290564  31.109064  27.927563  25.153216  22.513634
# CYOR3m  37.472065  34.290564  31.109064  27.927563  25.153216  22.513634
# GAPD    20.583523  19.533698  18.483873  17.434048  16.163779  14.812191
#
#                7          8          9          10
# ATPS4r  32.831587  28.413253  23.994920  20.282517
# NADH4   19.874052  17.234470  14.594888  12.443825
# CYOO3   19.874052  17.234470  14.594888  12.443825
# CYOR3m  19.874052  17.234470  14.594888  12.443825
# GAPD    13.460603  12.109016  10.757428   9.854504

# %%
# Out:
#                  1          2          3          4          5          6  \
# ATPS4r   62.612368  57.187515  51.762662  46.337809  41.668253  37.249920
# CYOR3m   37.472065  34.290564  31.109064  27.927563  25.153216  22.513634
# CYOO3    37.472065  34.290564  31.109064  27.927563  25.153216  22.513634
# NADH4    37.472065  34.290564  31.109064  27.927563  25.153216  22.513634
# GAPD     20.583523  19.533698  18.483873  17.434048  16.163779  14.812191
# ...            ...        ...        ...        ...        ...        ...
# XYLI2    -5.631888  -5.339026  -5.046164  -4.753302  -4.447794  -4.136912
# SUCCt2r  -6.645558  -5.989211  -5.332865  -4.676519  -3.849059  -2.960066
# PGM     -19.936114 -18.844353 -17.752591 -16.660830 -15.348626 -13.955102
# PGK     -20.583523 -19.533698 -18.483873 -17.434048 -16.163779 -14.812191
# H2Ot    -28.548917 -27.205035 -25.861154 -24.517272 -23.364948 -22.275488
#
#                  7          8          9         10  relative_change_in_flux
# ATPS4r   32.831587  28.413253  23.994920  20.282517                 1.676062
# CYOR3m   19.874052  17.234470  14.594888  12.443825                 1.667917
# CYOO3    19.874052  17.234470  14.594888  12.443825                 1.667917
# NADH4    19.874052  17.234470  14.594888  12.443825                 1.667917
# GAPD     13.460603  12.109016  10.757428   9.854504                 1.521243
# ...            ...        ...        ...        ...                      ...
# XYLI2    -3.826029  -3.515147  -3.204265  -3.042275                 1.459813
# SUCCt2r  -2.071073  -1.182080  -0.293086   0.000000                 2.000000
# PGM     -12.561578 -11.168054  -9.774530  -8.829671                 1.557102
# PGK     -13.460603 -12.109016 -10.757428  -9.854504                 1.521243
# H2Ot    -21.186028 -20.096569 -19.007109 -18.089174                 1.366380
#
# [167 rows x 11 columns]

# %%
def bar_color(df,color1,color2):
    return np.where(df.values >=0,color1,color2).T

fig = df.plot(legend=None, kind='bar', color=bar_color(df,'g','r'),figsize=(20, 4), grid =False);
fig.set_ylabel('Change in flux')
fig.set_xlabel('Gene names')
fig.set_title('Flux scanning based on Enforced Objective Flux', size=30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_38204/2315324958.py in <module>
#       2     return np.where(df.values >=0,color1,color2).T
#       3
# ----> 4 fig = df.plot(legend=None, kind='bar', color=bar_color(df,'g','r'),figsize=(20, 4), grid =False);
#       5 fig.set_ylabel('Change in flux')
#       6 fig.set_xlabel('Gene names')
#
# C:\Programs\Anaconda3\envs\cacfd\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# C:\Programs\Anaconda3\envs\cacfd\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# C:\Programs\Anaconda3\envs\cacfd\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     286         self._compute_plot_data()
#     287         self._setup_subplots()
# --> 288         self._make_plot()
#     289         self._add_table()
#     290         self._make_legend()
#
# C:\Programs\Anaconda3\envs\cacfd\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1446         import matplotlib as mpl
#    1447
# -> 1448         colors = self._get_colors()
#    1449         ncolors = len(colors)
#    1450
#
# C:\Programs\Anaconda3\envs\cacfd\lib\site-packages\pandas\plotting\_matplotlib\core.py in _get_colors(self, num_colors, color_kwds)
#     796             num_colors = self.nseries
#     797
# --> 798         return get_standard_colors(
#     799             num_colors=num_colors,
#     800             colormap=self.colormap,
#
# C:\Programs\Anaconda3\envs\cacfd\lib\site-packages\pandas\plotting\_matplotlib\style.py in get_standard_colors(num_colors, colormap, color_type, color)
#      68         return color
#      69
# ---> 70     colors = _derive_colors(
#      71         color=color,
#      72         colormap=colormap,
#
# C:\Programs\Anaconda3\envs\cacfd\lib\site-packages\pandas\plotting\_matplotlib\style.py in _derive_colors(color, colormap, color_type, num_colors)
#     124                 "'color' and 'colormap' cannot be used simultaneously. Using 'color'"
#     125             )
# --> 126         return _get_colors_from_color(color)
#     127     else:
#     128         return _get_colors_from_color_type(color_type, num_colors=num_colors)
#
# C:\Programs\Anaconda3\envs\cacfd\lib\site-packages\pandas\plotting\_matplotlib\style.py in _get_colors_from_color(color)
#     170
#     171     color = cast(Collection[Color], color)
# --> 172     return list(_gen_list_of_colors_from_iterable(color))
#     173
#     174
#
# C:\Programs\Anaconda3\envs\cacfd\lib\site-packages\pandas\plotting\_matplotlib\style.py in _gen_list_of_colors_from_iterable(color)
#     203             yield x
#     204         else:
# --> 205             raise ValueError(f"Invalid color {x}")
#     206
#     207
#
# ValueError: Invalid color ['g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g'
#  'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g'
#  'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g'
#  'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g'
#  'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g'
#  'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g'
#  'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'g' 'r'
#  'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r'
#  'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r'
#  'r' 'r' 'r' 'r' 'r' 'r' 'r']

# %%
df['relative_change_in_flux'] = abs(df[10]-df[1])/df[1] +1

# %%
#target_reactions_df = df[df['relative_change_in_flux'] > 1.8]

# %%
df= df.sort_values(['relative_change_in_flux'], ascending = False)

# %%
df
# Out:
#                        1         2         3         4         5         6  \
# GLYO1           0.029897  0.062262  0.094627  0.126992  0.159357  0.191722
# GART            0.030105  0.062450  0.094794  0.127139  0.159483  0.191827
# RPE             0.194107  0.174909  0.155712  0.136514  0.457035  0.897201
# DM_surfactin_c  0.032143  0.064286  0.096429  0.128571  0.160714  0.192857
# DPCOAK          0.032143  0.064286  0.096429  0.128571  0.160714  0.192857
# ...                  ...       ...       ...       ...       ...       ...
# KARA1          -0.604206 -0.756380 -0.908555 -1.060729 -1.212903 -1.365078
# RPI            -0.486121 -0.473365 -0.460609 -0.447853 -0.604956 -0.821881
# IPPMIa         -0.358359 -0.464204 -0.570049 -0.675894 -0.781740 -0.887585
# IPPMIb         -0.358359 -0.464204 -0.570049 -0.675894 -0.781740 -0.887585
# LLEUDr         -0.325355 -0.434464 -0.543574 -0.652683 -0.761793 -0.870902
#
#                        7         8         9        10  \
# GLYO1           0.224087  0.256452  0.288817  0.520449
# GART            0.224172  0.256516  0.288860  0.332798
# RPE             1.337368  1.777534  2.217701  2.108236
# DM_surfactin_c  0.225000  0.257143  0.289286  0.321429
# DPCOAK          0.225000  0.257143  0.289286  0.321429
# ...                  ...       ...       ...       ...
# KARA1          -1.517252 -1.669426 -1.821601 -1.973775
# RPI            -1.038807 -1.255733 -1.472659 -1.625630
# IPPMIa         -0.993430 -1.099276 -1.205121 -1.310966
# IPPMIb         -0.993430 -1.099276 -1.205121 -1.310966
# LLEUDr         -0.980011 -1.089121 -1.198230 -1.307339
#
#                 relative_change_in_flux
# GLYO1                         17.408068
# GART                          11.054576
# RPE                           10.861205
# DM_surfactin_c                10.000000
# DPCOAK                         9.999969
# ...                                 ...
# KARA1                         -1.266725
# RPI                           -1.344085
# IPPMIa                        -1.658248
# IPPMIb                        -1.658248
# LLEUDr                        -2.018192
#
# [155 rows x 11 columns]

# %%
df = target_reactions_df.drop(labels='relative_change_in_flux', axis=1)

# %%
fig = df.T.plot(cmap="viridis",figsize=(8, 8), grid =True, linewidth=3);
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))
fig.set_ylabel('Flux')
fig.set_title('Reactions with a relative change in Flux > 80%', size=20)
# Out:
# Text(0.5, 1.0, 'Reactions with a relative change in Flux > 80%')

# %%
#lowest flux reactions
target_reactions_df.tail()
# Out:
#                 1         2         3         4         5         6         7  \
# HACD2   -0.266172 -0.184406 -0.102640 -0.020875 -0.000000  0.000000 -0.000000
# ACACT7r -0.269839 -0.187710 -0.105582 -0.023454  0.000000  0.000000  0.000000
# HACD7   -0.301982 -0.251996 -0.202011 -0.152025 -0.160714 -0.192857 -0.225000
# ECOAH7  -0.301982 -0.251996 -0.202011 -0.152025 -0.160714 -0.192857 -0.225000
# SUCCt2r -6.645558 -5.989211 -5.332865 -4.676519 -3.849059 -2.960066 -2.071073
#
#                 8         9   10  relative_change_in_flux
# HACD2   -0.000000 -0.000000  0.0                      inf
# ACACT7r  0.000000  0.000000  0.0                      inf
# HACD7   -0.257143 -0.289286  0.0                      inf
# ECOAH7  -0.257143 -0.289286  0.0                      inf
# SUCCt2r -1.182080 -0.293086  0.0                      inf

# %%
#higest flux reactions
target_reactions_df.head()
# Out:
#                 1         2         3         4         5         6         7  \
# PGL      0.680228  0.648274  0.616321  0.584367  1.061991  1.719083  2.376175
# GND      0.680228  0.648274  0.616321  0.584367  1.061991  1.719083  2.376175
# G6PDH2r  0.680228  0.648274  0.616321  0.584367  1.061991  1.719083  2.376175
# ACOAD7   0.301982  0.251996  0.202011  0.152025  0.160714  0.192857  0.225000
# TKT1     0.194107  0.174909  0.155712  0.136514  0.287176  0.497661  0.708145
#
#                 8         9        10  relative_change_in_flux
# PGL      3.033267  3.690359  3.733866                 1.817822
# GND      3.033267  3.690359  3.733866                 1.817822
# G6PDH2r  3.033267  3.690359  3.733866                 1.817822
# ACOAD7   0.257143  0.289286 -0.000000                      inf
# TKT1     0.918630  1.129114  1.064783                 1.817703
